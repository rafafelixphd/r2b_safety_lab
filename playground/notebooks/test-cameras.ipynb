# %%
import r2b
from stable_baselines3.common.logger import make_output_format
from r2b.video import PS4EyeStereoCamera
from r2b.video.contants import OutputFormat
from IPython.display import display
from PIL import Image

# camera = PS4EyeStereoCamera(0, output_fmt=OutputFormat.PIL)
camera = PS4EyeStereoCamera(0, output_fmt="PIL")
idx, left, right = camera.current_frame

# %%
idx, left, right = camera.current_frame

# %%
import r2b.depth

# %%
# Out:
# <module 'r2b.depth.vanilla' from '/Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/depth/vanilla/__init__.py'>
