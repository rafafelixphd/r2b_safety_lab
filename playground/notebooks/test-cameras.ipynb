# %%
import r2b
from stable_baselines3.common.logger import make_output_format
from r2b.video import PS4EyeStereoCamera
from r2b.video.contants import OutputFormat
from IPython.display import display
from PIL import Image

# camera = PS4EyeStereoCamera(0, output_fmt=OutputFormat.PIL)
camera = PS4EyeStereoCamera(0, output_fmt="PIL")
idx, left, right = camera.current_frame
# Out:
# 2026-01-25 23:50:45.182 python[51630:16887943] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# [2026-01-25 23:50:46] ✨ INFO     Output format: OutputFormat.PIL                                   ]8;id=290243;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py\interface.py]8;;\:]8;id=60587;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py#59\59]8;;\
#                       ✨ INFO     Color mode: ColorSpace.BGR                                        ]8;id=788453;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py\interface.py]8;;\:]8;id=502672;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py#60\60]8;;\
#                       ✨ INFO     Target size: None                                                 ]8;id=909759;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py\interface.py]8;;\:]8;id=703849;file:///Users/rafaelfelix/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py#61\61]8;;\
# OutputFormat.PIL OutputFormat.PIL True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 from PIL import Image
#       8 camera = PS4EyeStereoCamera(0, output_fmt=OutputFormat.PIL)
# ----> 9 idx, left, right = camera.current_frame
#
# File ~/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py:137, in CameraInterface.current_frame(self)
#     135 @property
#     136 def current_frame(self) -> tuple[int, np.ndarray, np.ndarray]:
# --> 137     return next(self)
#
# File ~/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py:102, in CameraInterface.__next__(self)
#     100 if isinstance(raw_data, (list, tuple)):
#     101     idx, *frames = raw_data
# --> 102     return (idx, *(self._transform(f) for f in frames))
#     104 return self._transform(raw_data)
#
# File ~/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py:102, in <genexpr>(.0)
#     100 if isinstance(raw_data, (list, tuple)):
#     101     idx, *frames = raw_data
# --> 102     return (idx, *(self._transform(f) for f in frames))
#     104 return self._transform(raw_data)
#
# File ~/Projects/r2b/r2b_safety_lab/src/r2b/video/interface.py:74, in CameraInterface._transform(self, frame)
#      72 print(self.output_fmt, OutputFormat.PIL, self.output_fmt == OutputFormat.PIL)
#      73 if self.output_fmt == OutputFormat.PIL:
# ---> 74     return Image.fromarray(frame)
#      76 elif self.output_fmt == OutputFormat.JPEG:
#      77     _, buffer = cv2.imencode('.jpg', frame, [int(cv2.IMWRITE_JPEG_QUALITY), 90])
#
# NameError: name 'Image' is not defined

# %%
camera.output_fmt = OutputFormat.PIL
